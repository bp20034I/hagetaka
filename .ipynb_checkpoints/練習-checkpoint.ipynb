# %%
# main.py

# モジュールのインポート
from config import config                  # ハイパーパラメータの読み込み
from agent.reinforce_agent import REINFORCEAgent       # エージェントのインポートはここを変更
from environment.hagetaka_env import HagetakaEnv  # カスタム環境のインポート
from train.training_loop_v2 import train_agent  # トレーニングループのインポート

import os
import time


# モデルやログの保存用ディレクトリを作成
os.makedirs("saved_models", exist_ok=True)
os.makedirs("logs", exist_ok=True)

def main():
    # 環境とエージェントの初期化
    environment = HagetakaEnv()
    
    #エージェント名を変更する
    agent = REINFORCEAgent(config['agent']['state_size'], config['agent']['action_size'], config['agent']['learning_rate'])
    
    model_path = "saved_models/reinforce_agent_model.pth" # エージェントごとの学習状況を保存するパス
    try:
        agent.load(model_path)
        print(f"Loaded model from {model_path}")
    except FileNotFoundError:
        print(f"No model found at {model_path}. Please train the model first.")
        return

    start_time = time.time()
    
    # トレーニング開始
    print("Starting training...")
    train_agent(agent, environment, config['training']['n_episodes'], config['agent']['gamma'], config['training']['num_experiments'])  
    
    end_time = time.time()
    
    execution_time = end_time - start_time
    print(f"Execution time: {execution_time} seconds")
    
    # 学習済みモデルの保存
    agent.save("saved_models/reinforce_agent_model.pth") # エージェントごとに学習状況を保存
    print("Training complete. Model saved.")

if __name__ == "__main__":
    main()
# Out:
# Model loaded from saved_models/reinforce_agent_model.pth
# Loaded model from saved_models/reinforce_agent_model.pth
# Starting training...
# Running experiment 1/100
# Episode 100/200, Total Reward: 95
# Episode 200/200, Total Reward: 270
#
# Average score after 200 episodes:
#   Player 1: 12.14
#   Player 2: 5.39
#   Player 3: 9.00
#   Player 4: 12.37
#
# Last 10 Episodes - Score Cards and Player's Cards:
#
# Episode 1:
#   Score Cards   :  7  6 -5  5  4 -4  2  9 10 -1 -3  1  8  3 -2
#   Player 1 Cards: 10  7 15  3 14 11 12  8  9 13  4  1  2  5  6
#   Player 2 Cards: 15 14  1 13 12  2 11 10  9  3  4  8  7  6  5
#   Player 3 Cards:  6  7 15  9 12 14  2  5 11 13 10  3  4  8  1
#   Player 4 Cards:  5 15  1 14 13  2 12 11 10  3  8  9  7  6  4
#
# Episode 2:
#   Score Cards   :  5  8  2  3  9  4  7 -4 -3 -2 -5 -1  1  6 10
#   Player 1 Cards: 10  7 15  3 14 11 12 13  8  9  2  4  1  5  6
#   Player 2 Cards: 15 14 13 12 11 10  9  1  2  3  4  5  8  7  6
#   Player 3 Cards:  7 15 10 11 12  3  1 14 13  9  8  6  5  4  2
#   Player 4 Cards: 15 14 13 12 11 10  9  1  2  7  8  6  5  4  3
#
# Episode 3:
#   Score Cards   : -3 -4  1  6  8  3  2 -1 10  5 -2 -5  9  7  4
#   Player 1 Cards: 10  7 15 14  3 11  8 12 13  9  4  1  2  5  6
#   Player 2 Cards:  1  2 15 14 13 12 11  3 10  9  4  5  8  7  6
#   Player 3 Cards: 15 14  6  1 12  7 13 11  4  5 10  9  3  2  8
#   Player 4 Cards:  1  2 15 14 13 12 11  3 10  9  4  5  6  8  7
#
# Episode 4:
#   Score Cards   : -3 -2 -5  8  2  3  6 -1  5  4  7 -4 10  1  9
#   Player 1 Cards: 10  7 15 14 11  3 12  8 13  9  4  5  1  2  6
#   Player 2 Cards:  1  2  3 15 14 13 12  4 11 10  9  5  8  7  6
#   Player 3 Cards: 15 14 13  7  4  6 10 12  8  2 11  9  5  1  3
#   Player 4 Cards:  1  2  5 15 14 13 12  3 11 10  4  6  9  8  7
#
# Episode 5:
#   Score Cards   :  1  8 -2 10  2  3 -3  7  4 -4  5  6 -5  9 -1
#   Player 1 Cards: 10  7 15 14  3 11 12  8  9 13  4  1  2  5  6
#   Player 2 Cards: 15 14  1 13 12 11  2 10  9  3  8  7  4  6  5
#   Player 3 Cards:  1  3 15  2 12 10 14  9  5 13  6  4 11  8  7
#   Player 4 Cards: 15 14  1 11  3 13  2  9 12  4 10  8  5  7  6
#
# Episode 6:
#   Score Cards   :  6 -2  2 -3  3  7 -4  8 -1  5 -5  9 10  4  1
#   Player 1 Cards: 10  7 15  3 14 11 12  8  9  4 13  1  2  5  6
#   Player 2 Cards: 15  1 14  2 13 12  3 11  4 10  5  9  8  7  6
#   Player 3 Cards:  5 15  6 14 11  3 13  1 12  8 10  9  2  4  7
#   Player 4 Cards:  4  1 12  2 10 15  7 14  3 13  5  8  6 11  9
#
# Episode 7:
#   Score Cards   : -1  2 -4  6  3  9 -3  5 -5  8 -2  7  1  4 10
#   Player 1 Cards: 10  7 14 15 11 13 12  3  8  9  4  1  2  6  5
#   Player 2 Cards:  1 15  2 14 13 12  3 11  4 10  5  9  8  7  6
#   Player 3 Cards: 15  5 14  3  7  8 13 11 12  2 10  4  6  1  9
#   Player 4 Cards:  1 15  7  2 14 11  3 13  4 12  5  6 10  9  8
#
# Episode 8:
#   Score Cards   :  1  2 10  8  4  5  3 -4  6 -2  9 -5  7 -1 -3
#   Player 1 Cards: 10  7 15 14 11 12 13  3  9  8  1  2  4  5  6
#   Player 2 Cards: 15 14 13 12 11 10  9  1  8  2  7  3  6  4  5
#   Player 3 Cards:  5  9  4 13 11  6  1 15 14 12  2 10  8  7  3
#   Player 4 Cards: 15 14  2 13 12 11 10  1  9  3  8  4  7  5  6
#
# Episode 9:
#   Score Cards   :  9 -4  8  3  5 10  4 -2  6  2  1  7 -3 -1 -5
#   Player 1 Cards: 10  7 15 14 11  3 12 13  9  4  8  1  2  5  6
#   Player 2 Cards: 15  1 14 13 12 11 10  2  9  8  7  6  3  4  5
#   Player 3 Cards:  3 15  1  2  5  8 12 14  4  9 13 11 10  7  6
#   Player 4 Cards:  4  1 15 14 13 12  9  2 11 10  8  7  3  5  6
#
# Episode 10:
#   Score Cards   : 10 -2  3  6  4  8  1 -5  7 -4 -1  2  5  9 -3
#   Player 1 Cards: 10  7 15 14  3 11 13 12  8  9  5  4  1  2  6
#   Player 2 Cards: 15  1 14 13 12 11 10  2  9  3  4  8  7  6  5
#   Player 3 Cards:  9 15  4  8  7  1  5 14  3 13 12  6  2 11 10
#   Player 4 Cards: 15 11 14 13 12 10  9  1  8  2  3  7  6  5  4
# Graph saved as 'average_score.png'
# rank_scores_history shape: 4 200
# Graph saved as 'average_rank.png'
# Running experiment 2/100
# Episode 100/200, Total Reward: 189
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3531945/539877510.py in <module>
#      46
#      47 if __name__ == "__main__":
# ---> 48     main()
#
# /tmp/ipykernel_3531945/539877510.py in main()
#      34     # トレーニング開始
#      35     print("Starting training...")
# ---> 36     train_agent(agent, environment, config['training']['n_episodes'], config['agent']['gamma'], config['training']['num_experiments'])
#      37
#      38     end_time = time.time()
#
# ~/work/hagetaka/train/training_loop_v2.py in train_agent(agent, env, n_episodes, gamma, num_experiments)
#      46             player_card_history = [[] for _ in range(env.n_players)]  # 各プレイヤーが出したカードの順番
#      47
# ---> 48             while not done:
#      49                 action, log_prob = agent.get_action(state)  # 行動を選択
#      50                 next_state, reward, done, info = env.step(action)  # 環境で1ステップを実行
#
# ~/work/hagetaka/agent/reinforce_agent.py in get_action(self, state)
#      74         self.available_actions.remove(action - 1)  # available_actionsは0〜14の範囲で管理
#      75
# ---> 76         return action, action_dist.log_prob(action_idx)
#      77
#      78
#
# /usr/local/lib/python3.8/dist-packages/torch/distributions/categorical.py in log_prob(self, value)
#     121     def log_prob(self, value):
#     122         if self._validate_args:
# --> 123             self._validate_sample(value)
#     124         value = value.long().unsqueeze(-1)
#     125         value, log_pmf = torch.broadcast_tensors(value, self.logits)
#
# /usr/local/lib/python3.8/dist-packages/torch/distributions/distribution.py in _validate_sample(self, value)
#     296             return
#     297         assert support is not None
# --> 298         valid = support.check(value)
#     299         if not valid.all():
#     300             raise ValueError(
#
# /usr/local/lib/python3.8/dist-packages/torch/distributions/constraints.py in check(self, value)
#     255
#     256     def check(self, value):
# --> 257         return (value % 1 == 0) & (self.lower_bound <= value) & (value <= self.upper_bound)
#     258
#     259     def __repr__(self):
#
# KeyboardInterrupt:
